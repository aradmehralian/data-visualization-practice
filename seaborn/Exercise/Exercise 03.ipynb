# %% [markdown]
# # Seaborn Exercise 3

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("data/flight_delays.csv", index_col="Month")

# %%
df.head()
# Out:
#              AA        AS         B6        DL         EV         F9  \
# Month
# 1      6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238
# 2      7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179
# 3      6.693587 -0.544731  10.741317  2.077965   6.730101  20.074855
# 4      4.931778 -3.009003   2.780105  0.083343   4.821253  12.640440
# 5      5.173878 -1.716398  -0.709019  0.149333   7.724290  13.007554
#
#              HA         MQ         NK         OO        UA        US  \
# Month
# 1      3.512640  18.164974  11.398054  10.889894  6.352729  3.107457
# 2      6.029967  21.301627  16.474466   9.588895  7.260662  7.114455
# 3      3.468383  11.018418  10.039118   3.181693  4.892212  3.330787
# 4      0.011022   5.131228   8.766224   3.223796  4.376092  2.660290
# 5      0.826426   5.466790  22.397347   4.141162  6.827695  0.681605
#
#              VX        WN
# Month
# 1      1.420702  3.389466
# 2      7.784410  3.501363
# 3      5.348207  3.263341
# ...

# %%
df.index = pd.to_datetime(df.index, format="%m").strftime("%B")

# %%
df
# Out:
#                  AA        AS         B6        DL         EV         F9  \
# Month
# January    6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238
# February   7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179
# March      6.693587 -0.544731  10.741317  2.077965   6.730101  20.074855
# April      4.931778 -3.009003   2.780105  0.083343   4.821253  12.640440
# May        5.173878 -1.716398  -0.709019  0.149333   7.724290  13.007554
# June       8.191017 -0.220621   5.047155  4.419594  13.952793  19.712951
# July       3.870440  0.377408   5.841454  1.204862   6.926421  14.464543
# August     3.193907  2.503899   9.280950  0.653114   5.154422   9.175737
# September -1.432732 -1.813800   3.539154 -3.703377   0.851062   0.978460
# October   -0.580930 -2.993617   3.676787 -5.011516   2.303760   0.082127
# November   0.772630 -1.916516   1.418299 -3.175414   4.415930  11.164527
# December   4.149684 -1.846681  13.839290  2.504595   6.685176   9.346221
#
# ...

# %%
fig, ax = plt.subplots(figsize=(12, 6))
title_params = dict(fontweight="bold", fontsize=12)

sns.barplot(data=df, ax=ax, x="Month", y="NK", palette="Set3", hue="Month")
ax.set_title("Average Arrival Delay for Spirit Airlines' Flights", title_params)
ax.set_ylabel("Flight Delay (minutes)")

fig.tight_layout()

# %%
ax = sns.heatmap(data=df, cmap="rocket", annot=True)
ax.set_xlabel("Airline")
ax.set_title("Average Arrival Delay for Each Airline, by Month", title_params)

ax.figure.set_size_inches((10, 7))
ax.figure.tight_layout()

# %% [markdown]
# ### Exercises

# %%
df = pd.read_csv("data/ign_scores.csv", index_col="Platform")

# %%
# 1
df.head()
# Out:
#                     Action  Action, Adventure  Adventure  Fighting  \
# Platform
# Dreamcast         6.882857           7.511111   6.281818  8.200000
# Game Boy Advance  6.373077           7.507692   6.057143  6.226316
# Game Boy Color    6.272727           8.166667   5.307692  4.500000
# GameCube          6.532584           7.608333   6.753846  7.422222
# Nintendo 3DS      6.670833           7.481818   7.414286  6.614286
#
#                   Platformer    Puzzle       RPG    Racing   Shooter  \
# Platform
# Dreamcast           8.340000  8.088889  7.700000  7.042500  7.616667
# Game Boy Advance    6.970588  6.532143  7.542857  6.657143  6.444444
# Game Boy Color      6.352941  6.583333  7.285714  5.897436  4.500000
# GameCube            6.665714  6.133333  7.890909  6.852632  6.981818
# Nintendo 3DS        7.503448  8.000000  7.719231  6.900000  7.033333
#
#                   Simulation    Sports  Strategy
# Platform
# Dreamcast           7.628571  7.272222  6.433333
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21 entries, Dreamcast to iPhone
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Action             21 non-null     float64
#  1   Action, Adventure  21 non-null     float64
#  2   Adventure          21 non-null     float64
#  3   Fighting           21 non-null     float64
#  4   Platformer         21 non-null     float64
#  5   Puzzle             21 non-null     float64
#  6   RPG                21 non-null     float64
#  7   Racing             21 non-null     float64
#  8   Shooter            21 non-null     float64
#  9   Simulation         21 non-null     float64
#  10  Sports             21 non-null     float64
#  11  Strategy           21 non-null     float64
# dtypes: float64(12)
# memory usage: 2.1+ KB

# %%
df.isnull().any()
# Out:
# Action               False
# Action, Adventure    False
# Adventure            False
# Fighting             False
# Platformer           False
# Puzzle               False
# RPG                  False
# Racing               False
# Shooter              False
# Simulation           False
# Sports               False
# Strategy             False
# dtype: bool

# %%
list(df.index)
# Out:
# ['Dreamcast',
#  'Game Boy Advance',
#  'Game Boy Color',
#  'GameCube',
#  'Nintendo 3DS',
#  'Nintendo 64',
#  'Nintendo DS',
#  'Nintendo DSi',
#  'PC',
#  'PlayStation',
#  'PlayStation 2',
#  'PlayStation 3',
#  'PlayStation 4',
#  'PlayStation Portable',
#  'PlayStation Vita',
#  'Wii',
#  'Wireless',
#  'Xbox',
#  'Xbox 360',
#  'Xbox One',
#  'iPhone']

# %%
df.describe().round(decimals=2)
# Out:
#        Action  Action, Adventure  Adventure  Fighting  Platformer  Puzzle  \
# count   21.00              21.00      21.00     21.00       21.00   21.00
# mean     6.71               7.51       6.76      6.86        7.30    7.04
# std      0.44               0.50       0.64      0.81        0.59    0.77
# min      5.90               6.13       5.31      4.50        6.35    5.12
# 25%      6.47               7.29       6.28      6.55        6.89    6.58
# 50%      6.72               7.48       6.82      7.03        7.25    6.92
# 75%      6.87               7.76       7.14      7.42        7.51    7.46
# max      7.70               8.50       8.06      8.20        8.57    8.25
#
#          RPG  Racing  Shooter  Simulation  Sports  Strategy
# count  21.00   21.00    21.00       21.00   21.00     21.00
# mean    7.54    6.76     7.01        6.98    6.91      7.22
# std     0.52    0.64     0.76        0.95    0.63      0.64
# min     6.05    5.01     4.50        5.20    5.64      6.43
# ...

# %%
df.agg(["count", "mean", "max", "min"]).round(decimals=2)
# Out:
#        Action  Action, Adventure  Adventure  Fighting  Platformer  Puzzle  \
# count   21.00              21.00      21.00     21.00       21.00   21.00
# mean     6.71               7.51       6.76      6.86        7.30    7.04
# max      7.70               8.50       8.06      8.20        8.57    8.25
# min      5.90               6.13       5.31      4.50        6.35    5.12
#
#          RPG  Racing  Shooter  Simulation  Sports  Strategy
# count  21.00   21.00    21.00       21.00   21.00     21.00
# mean    7.54    6.76     7.01        6.98    6.91      7.22
# max     8.29    8.16     8.04        9.25    7.88      8.90
# min     6.05    5.01     4.50        5.20    5.64      6.43

# %%
# 2
df.loc["PC"].max()
# Out:
# 7.759930313588847

# %%
df.loc["PlayStation Vita"]
# Out:
# Action               7.173077
# Action, Adventure    6.133333
# Adventure            8.057143
# Fighting             7.527273
# Platformer           8.568750
# Puzzle               8.250000
# RPG                  7.337500
# Racing               6.300000
# Shooter              7.660000
# Simulation           5.725000
# Sports               7.130000
# Strategy             8.900000
# Name: PlayStation Vita, dtype: float64

# %%
df.loc["PlayStation Vita"].idxmin()
# Out:
# 'Simulation'

# %%
df.loc["PlayStation Vita", "Simulation"]
# Out:
# np.float64(5.725)

# %%
df.loc["PlayStation Vita"].min()
# Out:
# 5.725

# %%
# 3
df.head()
# Out:
#                     Action  Action, Adventure  Adventure  Fighting  \
# Platform
# Dreamcast         6.882857           7.511111   6.281818  8.200000
# Game Boy Advance  6.373077           7.507692   6.057143  6.226316
# Game Boy Color    6.272727           8.166667   5.307692  4.500000
# GameCube          6.532584           7.608333   6.753846  7.422222
# Nintendo 3DS      6.670833           7.481818   7.414286  6.614286
#
#                   Platformer    Puzzle       RPG    Racing   Shooter  \
# Platform
# Dreamcast           8.340000  8.088889  7.700000  7.042500  7.616667
# Game Boy Advance    6.970588  6.532143  7.542857  6.657143  6.444444
# Game Boy Color      6.352941  6.583333  7.285714  5.897436  4.500000
# GameCube            6.665714  6.133333  7.890909  6.852632  6.981818
# Nintendo 3DS        7.503448  8.000000  7.719231  6.900000  7.033333
#
#                   Simulation    Sports  Strategy
# Platform
# Dreamcast           7.628571  7.272222  6.433333
# ...

# %%
fig, ax = plt.subplots(figsize=(12, 8))
sns.barplot(data=df, ax=ax, x="Racing", y="Platform", hue="Platform", palette="Set2", gap=0.1)
ax.set_title("Average Score of Racing Games, by Platform", fontweight="bold", fontsize=12)

fig.tight_layout()

# %%
df["Racing"].idxmin()
# Out:
# 'Wii'

# %%
df["Racing"].idxmax()
# Out:
# 'Xbox One'

# %%
df.loc["Xbox One", "Racing"]
# Out:
# np.float64(8.163636363636364)

# %%
# 4
fig, ax = plt.subplots(figsize=(12, 8))
sns.heatmap(data=df, ax=ax, cmap="coolwarm", annot=True, fmt=".2f")

for label in ax.get_xticklabels():
    label.set(rotation=45, ha="right")

fig.tight_layout()
